# %%
motor = ["Vario", "Kendaraan Bermotor", 150 , "Hitam", "Roda Dua"]
print(motor)

motor.append(15000000)
motor.append("matic")
print(motor)

motor.insert(2, "Honda")
print(motor)
# Out:
# ['Vario', 'Kendaraan Bermotor', 150, 'Hitam', 'Roda Dua']
# ['Vario', 'Kendaraan Bermotor', 150, 'Hitam', 'Roda Dua', 15000000, 'matic']
# ['Vario', 'Kendaraan Bermotor', 'Honda', 150, 'Hitam', 'Roda Dua', 15000000, 'matic']

# %%
a = int(input("""ketik 1 untuk menghitung luas persegi
ketik 2 untuk menghitung luas lingkaran
ketik 3 untuk menghitung luas segitiga"""))
match a:
 case 1:
  s = int(input("Masukan sisi persegi: "))
  luas = (s*s)
  print("Luas Persegi: ", luas)
 case 2:
  r = int(input("Masukan jari jari lingkaran: "))
  luas = (22/7 * r ** 2)
  print("Luas Lingkaran: ", luas)
 case 3:
  alas = int(input("Masukan alas segitiga: "))
  tinggi = int(input("Masukan tinggi segitiga: "))
  luas = (0.5 * alas * tinggi)
  print("Luas segitiga: ", luas)
 case _:
  print("Salah pilih! Masukan angka dengan benar")
# Out:
# ketik 1 untuk menghitung luas persegi
# ketik 2 untuk menghitung luas lingkaran
# ketik 3 untuk menghitung luas segitiga3
# Masukan alas segitiga: 5
# Masukan tinggi segitiga: 5
# Luas segitiga:  12.5
